# %%
import pandas as pd
import numpy as pn

# %%
data = pd.read_csv('C:/Users/Maura Santos/Desktop/DA_FT_OUT/Modulo_1/archive(2)/attacks.csv', encoding='latin1', sep=',')
data
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
import seaborn as sns

# %%
print(data.columns.tolist())
# Out:
# ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23']

# %%
import seaborn as sns

# %%
program = shipwreck.dropna(thresh =  0.8*len(shipwreck.columns))

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(program.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
print(program.columns.tolist())
# Out:
# ['Case Number', 'Year', 'Country', 'Area', 'Fatal (Y/N)', 'Species ', 'Location', 'Activity']

# %%
#a renomear a coluna
program = program.rename(columns={'Species ':'Species'})

# %%
 program = program[['Country','Area','Fatal (Y/N)','Species']]
program
# Out:
#                  Country               Area Fatal (Y/N)  \
# 0                    USA         California           N
# 1                    USA            Georgia           N
# 2                    USA             Hawaii           N
# 3              AUSTRALIA    New South Wales           N
# 4                 MEXICO             Colima           N
# ...                  ...                ...         ...
# 6290        SOUTH AFRICA      KwaZulu-Natal           Y
# 6296           AUSTRALIA    New South Wales           Y
# 6297           AUSTRALIA  Western Australia           Y
# 6299                 USA     North Carolina           Y
# 6301  CEYLON (SRI LANKA)   Eastern Province           Y
#
#                                                 Species
# 0                                           White shark
# 1                                                   NaN
# 2                                                   NaN
# 3                                             2 m shark
# 4                                       Tiger shark, 3m
# ...                                                 ...
# 6290                                                NaN
# 6296  Said to involve a grey nurse shark that leapt ...
# 6297                                                NaN
# 6299                                                NaN
# 6301                                                NaN
#
# [5315 rows x 4 columns]

# %%
program = program.dropna(subset=['Country','Area','Fatal (Y/N)','Species'])
program
# Out:
#            Country              Area Fatal (Y/N)  \
# 0              USA        California           N
# 3        AUSTRALIA   New South Wales           N
# 4           MEXICO            Colima           N
# 6           BRAZIL        Pernambuco           Y
# 7              USA           Florida           N
# ...            ...               ...         ...
# 6265          IRAQ            Basrah           Y
# 6266  SAUDI ARABIA  Eastern Province           Y
# 6267  SAUDI ARABIA  Eastern Province           N
# 6274         ITALY      Adriatic Sea           N
# 6296     AUSTRALIA   New South Wales           Y
#
#                                                 Species
# 0                                           White shark
# 3                                             2 m shark
# 4                                       Tiger shark, 3m
# 6                                           Tiger shark
# 7                                       Lemon shark, 3'
# ...                                                 ...
# 6265                                         Bull shark
# 6266                             "a black-tipped shark"
# 6267                                           6' shark
# 6274                                        White shark
# 6296  Said to involve a grey nurse shark that leapt ...
#
# [2823 rows x 4 columns]

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(program.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
#selecionar apenas os casos fatais
fatal = program['Fatal (Y/N)'] == 'Y'
program[fatal]
# Out:
#            Country                          Area Fatal (Y/N)  \
# 6           BRAZIL                    Pernambuco           Y
# 58      COSTA RICA                  Cocos Island           Y
# 64            CUBA              Holquin Province           Y
# 155      AUSTRALIA             Western Australia           Y
# 267      AUSTRALIA             Western Australia           Y
# ...            ...                           ...         ...
# 6240    SEYCHELLES              Amirante Islands           Y
# 6253     NICARAGUA  Lake Nicaragua (fresh water)           Y
# 6265          IRAQ                        Basrah           Y
# 6266  SAUDI ARABIA              Eastern Province           Y
# 6296     AUSTRALIA               New South Wales           Y
#
#                                                 Species
# 6                                           Tiger shark
# 58                                  Tiger shark, female
# 64                                          Tiger shark
# 155                                         White shark
# 267                                          3+ m shark
# ...                                                 ...
# 6240                                        Tiger shark
# 6253  Bull shark caught, leg recovered & buried besi...
# 6265                                         Bull shark
# 6266                             "a black-tipped shark"
# 6296  Said to involve a grey nurse shark that leapt ...
#
# [392 rows x 4 columns]

# %%
program[['Species']]
# Out:
#                                                 Species
# 0                                           White shark
# 3                                             2 m shark
# 4                                       Tiger shark, 3m
# 6                                           Tiger shark
# 7                                       Lemon shark, 3'
# ...                                                 ...
# 6265                                         Bull shark
# 6266                             "a black-tipped shark"
# 6267                                           6' shark
# 6274                                        White shark
# 6296  Said to involve a grey nurse shark that leapt ...
#
# [2823 rows x 1 columns]

# %%
import re
def specie_names(x):
    if isinstance(x,str):
        shark_name = '[a-zA-Z]{3,} [a-zA-Z]{3,} *[Ss]hark|[a-zA-Z]{3,} *[Ss]hark'
        str_shark = ' '.join(re.findall(shark_name,x)).lower()
        replace_dic = {'juvenile ': '','slim ': '','probable ': '','carcharinid ': '',
        'involve ': '','but ': '','metre ': '','little ': '','the shark': '',
        'small ': '','possible ': '','old ': '','captive ': '','large ': '',
        'dead ': '','dusk ': '','young ': '','female ': '','two ': '',
        'authorities believed ': '','cold for shark pregnant ': '','believed ': '','six ': '',
        'spinner shark blacktip shark': 'spinner shark','white shark oceanic whitetip shark': 'white shark',
        'blue shark blue shark': 'blue shark','dusky ': 'black',
        'bull shark bull shark': 'bull shark','bull shark caribbean reef shark': 'bull shark',
        'sandbar shark blacktip shark': 'black shark','the same shark': '','great hammerhead shark': 'hammerhead shark',
        'white shark white shark': 'white shark','tiger shark bull shark': 'tiger shark',
        'blacktip  shark bamboo catshark': 'catshark','dusky shark blackfin shark': 'black shark',
        'oceanic whitetip shark white shark': 'white shark','blacktip shark caribbean reef shark': 'black reef shark',
        'possiby white shark': 'white shark','unidentified shark': '','bull shark lemon shark': 'bull shark',
        'silvertip shark': 'grey shark','tiger shark hammerhead shark': 'tiger shark','lemon shark sandtiger shark': 'lemon shark',
        'cfor shark pregnant sandbar shark': '','grey reef shark grey reef shark': 'grey shark',
        'dusky shark dusky shark': 'dusky shark','lemon shark lemon shark': 'lemon shark',
        'larger shark': '','blacktail reef shark': '','hammerhead shark other shark': 'hammerhead shark',
        'several shark': '','white shark blue shark': 'white shark','whtietip reef shark': 'white reef shark',
        'blacktip shark spinner shark': 'spinner shark','bonita ': 'mako','bonito ': 'mako',
        'mako shark aka bonito shark': 'mako shark','tubarão carcharhinid': '','whiptail shark thresher shark': 'whiptail shark',
        'white shark sevengill shark': 'broadnose shark','very shark': '','white shark captured shark': 'white shark',
        'comrades saw shark': '','remains from shark': '', 'ground shark': '','recovered from shark': '',
        'tipped shark': ''}
        for i in replace_dic:
            str_shark = str_shark.replace(i,replace_dic[i])
        
        return(str_shark)

# %%
program['Species'].apply(specie_names).value_counts().head(177)
# Out:
#                               941
# white shark                   610
# tiger shark                   246
# bull shark                    160
# shark                          70
# bronze whaler shark            59
# blacktip shark                 56
# nurse shark                    48
# spinner shark                  44
# mako shark                     43
# hammerhead shark               43
# raggedtooth shark              43
# wobbegong shark                42
# grey nurse shark               39
# lemon shark                    34
# blue shark                     33
# zambesi shark                  23
# oceanic whitetip shark         20
# sandtiger shark                20
# sand shark                     16
# reef shark                     14
# grey reef shark                14
# caribbean reef shark           13
# blackshark                     11
# blacktip reef shark            10
# sevengill shark                 9
# basking shark                   7
# carpet shark                    7
# gill shark                      7
# galapagos shark                 7
# angel shark                     6
# whaler shark                    6
# dog shark                       6
# porbeagle shark                 5
# sandbar shark                   5
# copper shark                    5
# grey shark                      5
# colored shark                   5
# whitetip reef shark             4
# foot shark                      4
# silky shark                     4
# shortfin mako shark             4
# zambezi shark                   3
# tawny nurse shark               3
# brown shark                     3
# bull shark tiger shark          2
# thresher shark                  2
# leopard shark                   2
# shovelnose shark                2
# catshark                        2
# cow shark                       2
# broadnose sevengill shark       2
# blue nose shark                 2
# salmon shark                    2
# sevengill  shark                2
# whale shark                     2
# longfin mako shark              1
# makoshark                       1
# gray reef shark                 1
# broadnose shark                 1
# port jackson shark              1
# bonnethed shark                 1
# soupfin shark                   1
# blackshark blackshark           1
# gray shark                      1
# dogfish shark                   1
# black finned shark              1
# white reef shark                1
# tipped reef shark               1
# mako shark aka makoshark        1
# grey colored shark              1
# bull shark                      1
# cookie cutter shark             1
# nosed shark                     1
# lemon shark bull shark          1
# carcharhinid shark              1
# blackshark blackfin shark       1
# scalloped hammerhead shark      1
# cookiecutter shark              1
# whiptail shark                  1
# blue shark                      1
# red shark                       1
# black shark                     1
# shot white shark                1
# been another shark              1
# spotted catshark                1
# white shark gill shark          1
# white shark thresher shark      1
# gaffed shark                    1
# reef shark colored shark        1
# cocktail shark                  1
# sandshark                       1
# white shark shark               1
# starry smoothhound shark        1
# hooked shark                    1
# bronze whale shark              1
# banjo shark                     1
# shark mako shark                1
# tawney nurse shark              1
# black reef shark                1
# Name: Species, dtype: int64

# %%
 program['Species_2'] = program['Species'].apply(specie_names)
# Out:
# <ipython-input-509-a272ace32cb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   program['Species_2'] = program['Species'].apply(specie_names)

# %%
program['Species_2'].value_counts().head()
# Out:
#                941
# white shark    610
# tiger shark    246
# bull shark     160
# shark           70
# Name: Species_2, dtype: int64

# %%
len([white shark])
# Out:
#   File "<ipython-input-560-507af970442d>", line 1
#     len([white shark])
#                ^
# SyntaxError: invalid syntax

# %%
program['Species_2'].unique()
# Out:
# array(['white shark', '', 'tiger shark', 'lemon shark', 'bull shark',
#        'grey reef shark', 'tawny nurse shark', 'wobbegong shark',
#        'blacktip shark', 'galapagos shark', 'shark', 'nurse shark',
#        'cookiecutter shark', 'spinner shark', 'oceanic whitetip shark',
#        'sandtiger shark', 'blue shark', 'gill shark',
#        'caribbean reef shark', 'broadnose sevengill shark', 'reef shark',
#        'angel shark', 'dogfish shark', 'mako shark', 'silky shark',
#        'bronze whaler shark', 'hammerhead shark', 'foot shark',
#        'blacktip reef shark', 'raggedtooth shark', 'sandbar shark',
#        'tawney nurse shark', 'cow shark', 'whitetip reef shark',
#        'salmon shark', 'grey nurse shark', 'porbeagle shark',
#        'port jackson shark', 'sevengill shark', 'zambesi shark',
#        'thresher shark', 'bronze whale shark', 'cookie cutter shark',
#        'blackshark', 'white shark gill shark', 'starry smoothhound shark',
#        'basking shark', 'gray reef shark', 'sand shark',
#        'spotted catshark', 'catshark', 'black shark', 'copper shark',
#        'longfin mako shark', 'sevengill  shark', 'brown shark',
#        'shortfin mako shark', 'colored shark', 'reef shark colored shark',
#        'grey colored shark', 'bull shark tiger shark', 'bonnethed shark',
#        'whaler shark', 'black finned shark', 'blackshark blackfin shark',
#        'soupfin shark', 'leopard shark', 'black reef shark', 'grey shark',
#        'gaffed shark', 'zambezi shark', 'white shark shark',
#        'tipped reef shark', 'shot white shark', 'sandshark', 'gray shark',
#        'lemon shark bull shark', 'whale shark', 'carpet shark',
#        'dog shark', 'scalloped hammerhead shark',
#        'white shark thresher shark', 'red shark', 'banjo shark',
#        'hooked shark', 'blackshark blackshark', 'shark mako shark',
#        'been another shark', 'blue shark ', 'bull shark ',
#        'white reef shark', 'makoshark', 'mako shark aka makoshark',
#        'shovelnose shark', 'blue nose shark', 'nosed shark',
#        'cocktail shark', 'carcharhinid shark', 'whiptail shark',
#        'broadnose shark'], dtype=object)

# %%
program[program['Species_2'] == '']['Species'].unique()
# Out:
# array(['2 m shark', 'Invalid incident', 'Shark involvement not confirmed',
#        'Questionable', '3 m shark', "6' shark", '3.5 m shark',
#        '1.8 m shark', 'Possibly a wobbegong',
#        'Injury believed caused by an eel, not a shark', '2m shark',
#        "8' shark", "5' shark", "4' to 5' shark", 'Porbeagle, 1.5 m',
#        "5' to 6' shark", "4' shark", '3m shark, probably a smooth hound',
#        "3' shark", "9' shark", "10' shark", " 6' to 8' shark",
#        "3' to 4' shark", "3' to 5' shark", '3+ m shark', 'Bronze whaler',
#        'Hammerhead sp.', "4' shark?", "6' to 7' shark",
#        '1m to 1.2 m shark', '3.5 to 4 m shark', '2 m to  3 m shark',
#        '5 m shark', '1.5 m shark', "2' shark", "12' to 14' shark",
#        '1 m shark', "8' to 10' shark", "7' shark", "4' to 6' shark",
#        "4' tp 5' shark", "6' to 8' shark", '3m shark', '1m shark',
#        'Wobbegong, 2m', '2.5 m shark', "2' to 3' shark",
#        "3.5' to 4' shark", '4.5 m shark', "14' to 18'shark", "15' shark",
#        '18" to 24" shark', "7' to 8' shark ", "10' to 12' shark",
#        '4 m shark', "1' to 2' shark", '3 m to 4 m shark',
#        '20 to 30kg shark', "14' shark", '2 m to 3 m shark', 'Spurdog',
#        'Shark involvement prior to death not confirmed', '80 kg shark',
#        "5' to 8' shark", '2.6 m shark', "+3' shark", "3'  shark",
#        "2'  shark", "4.5 to 5' shark", "1.5' to 2' shark", "2.5' shark",
#        '2.27 m shark', '1.5 to 2 m shark', "9.5' shark?", ' ',
#        'Lesser spotted dogfish, Scyliorhinus canicula, less than 80 cm in length',
#        '2 to 2.5 m shark', '2.4 m shark', '2.5 to 3 m shark',
#        '2 to 3 m shark', "1' to 4' shark", "3' to 3.5' shark",
#        '1.8 m blacktip "reef" shark', '3 m, 600-kg shark',
#        "5' to 7' shark", "12' to 18' shark", "12' shark",
#        'Said to involve a 1.5 m shark', "1.8 m [6'] shark",
#        "3.5 m [11.5']shark", "[4.5' to 5'] shark", "[4' to 5']",
#        'On 8/13/2005 anglers from New Zealand caught a 2.8 m [9\'3"], 140-kg [309-lb] shark at the same spot. It was believed this was the same shark that killed Alysha',
#        'Unknown, but it was reported that a shark tooth was recovered from the wound',
#        '18" to 36" shark', "4 m [13'] shark", "3 m [10'] shark",
#        "2.4 m [8'] shark", "1.2 m [4'] shark",
#        "1.2 m to 1.5 m [4' to 5'] shark", '2 sharks, 4.5 m & 3 m ',
#        '"black tipped" shark', "0.9 m to 1.5 m [3' to 5'] shark",
#        "2.4 m to 3.7 m [8' to 12'] shark", 'Questionable Incident',
#        'Shark involvement prior to death was not confirmed',
#        'Unidentified species', "1.5 m to 1.8 m [5' to 6'] shark",
#        "106 cm [3.5']  shark", "3.7 m to 4.3 m [12' to 14'] shark",
#        "0.9 m to 1.2 m [3' to 4'] shark", 'A \x93small\x94 shark',
#        '15 cm to 20 cm [6" to 8"] bite diameter just below left knee',
#        'Species unidentified', "3.5' to 4.5' shark",
#        "3 m to 3.7 m [10' to 12'] shark",
#        "0.9 m  to 1.2 m [3' to 4'] shark",
#        "0.9 m to 1.2 m [3' to 4'] shark; Tooth fragment recovered from hand",
#        '\xa0 ', '1 m  shark', "2.1 m to 2.4 m [7' to 8'] shark",
#        "0.9 m [3'] shark",
#        'C. leucas tooth fragment recovered from kayak', 'Unidentified',
#        'Questionable incident - shark bite may have precipitated drowning',
#        "2' to 3.5' shark", "1.5 m [5'] shark", "0.9 m  [3'] shark",
#        "1.2 m to 1.5 m [4.5' to 5'] shark", "2 m [6.75'] shark",
#        "6 m [20'] shark", "1.2 m to 1.8 m [4' to 6'] shark",
#        "2.1 to 2.4 m [7' to 8'] shark", "60 cm to 90 cm [2' to 3'] shark",
#        "A 2' shark was seen in the area by witnesses",
#        "2 m to 2.5 m [6.75'  to 8.25'] shark", '1.3 to 1.6 m shark',
#        '200 to 300 kg shark',
#        "3.7 m to 4.6 m [12' to 15'] shark seen in the vicinity",
#        "4.5' to 5' shark", "1.8 m [6'] shark, possibly a blacktip",
#        '1.7 m shark', "1.8 m to 2.1 m [6' to 7'] shark",
#        'Shark involvement prior to death suspected but not confirmed',
#        "1.2 m to 1.5 m [4' to 5']   shark",
#        "1.5 to 1.8 m [5' to 6'] shark", '"sand" shark',
#        "Two 1.2 m to 1.5 m [4' to 5'] sharks", "3.7 m [12'] shark",
#        "2.7 m [9'] shark", "2.1 m [7'] shark", ">1.8 m [6'] shark",
#        '1.3 m [4\'3"] shark',
#        "1.8 m to 2.4 m [6' to 8'] shark, tooth fragments recovered ",
#        'Unidentified shark', '>2 m shark', "5 m [16.5'] shark",
#        "3 m [10'], 270- kg [595-lb] shark", '170-kg, 2.8 m shark',
#        '"Shark had a very large girth"', "1.8 m [6'] shark ",
#        "1.8 m to 2.4 m [6' to 8'] shark", '6 m, 600-kg shark',
#        '2 m hammerhead', '2 m shark, possibly a bronze whaler',
#        '150-lb shark', "1.5 m to 2 m [5' to 6.75'] shark",
#        '1 m "grey-colored" shark', '6 m shark',
#        '40 to 50 sharks attacked survivors in the water', '4.3 m shark',
#        '1.6 m shark', '>1 m shark', "6', 100-lb shark",
#        '30-kg [66-lb] shark', "2.5 m [8.25'] shark", '.5 m shark',
#        "4.5' shark", "3 m to 4 m [10' to 13'] shark",
#        '2.1 m [7\'] shark with "a very flat head\x94 that had followed the boat for 3 days',
#        "1.8 m [6'] shark, species identity questionable",
#        'C. maculpinnis or C. limbatus', "3.5 m [11.5'] shark",
#        "4' to 8' shark", '2.2 m shark', '2 m [6\'9"] shark',
#        '270 kg shark', "1.5 to 2 m [5' to 6.75'] shark",
#        "2.7 m  [9'] shark", "1.5 m [5']  shark", "3.7 m [12'] sharks",
#        "1.2 m to 1.8 m [4' to 6'] shark observed in area",
#        '1.5 m to 2 m shark', '1.8 to 2 m C. albimarginatus', "7.5' shark",
#        ">2.4 m [8'] shark", '90-kg "blackfin" shark', "4m [13'] shark",
#        '"Blue whaler" (Galeolamna)', "1.5 m to 1.8m [5' to 6'] shark",
#        'A pack of 6 sharks',
#        "Local authorities speculated that the water was too cold for sharks, but a 2.1 m [7'], 200-lb pregnant sandbar shark was caught next day",
#        '1.8 m to 2 m [6\' to 6\'9"] shark', "4.6 m [15'] shark",
#        "1.8 m [6'], 180-lb shark", '2 sharks involved',
#        '300-kg [662-lb] shark', "1.8 m [6'], 136-kg [300-lb] shark ",
#        "4.9 m [16'] whaler", "1.8 to 2.4 m [6' to 8'] shark",
#        "Less than 1.2 m [4']", "1.7 m [5.5'] shark", 'Wobbegong',
#        "2.1 m to 2.4 m  [7' to 8'] shark", "1.8 m [6']  shark",
#        "4.3 m [14'], 1000-lb shark",
#        'Dooley believed his Injury was caused by stingray (Dasyatidae family)',
#        '500-lb shark', "5.5 m [18'] shark", '8 sharks',
#        "1.8 m to 2.4 m  [6' to 8'] shark",
#        "3.7 to 4.5 m [12' to 15'] shark seen in vicinity", '193-lb shark',
#        '<1.5 m shark', '2 m [6\'9"], 87.5-kg [193-lb]  shark',
#        "3 m [10'] blue whaler",
#        "Horn shar,k Heterodontus francisci, 1.2 m [4'] ",
#        "4.3 m [14'] shark", 'Unknown', "2.7 m to 3 m [9' to 10'] sharks",
#        "4.9 m [16']shark", "1.2 m  [4'] shark", '60 cm  shark ',
#        '36"  shark',
#        "Next morning a 3 m [10'] shark was caught that had Andrews' leg in its gut",
#        'Oceanic whitetip shar,; identified by Dr. W.C. Schoeder on photograph & Dr. L.P. L. Schultz on sketch by observer',
#        "1.5 m to 1.8 m  [5' to 6'] shark", '43" shark', "2.7 m [9']shark",
#        ' "gummy" shark (Rhizoprionodon or Loxodon) 1.2 m [4\']',
#        "2.1 m [7'], 90-kg shark", '> 3 m shark',
#        "2.4 m [8'], 600-lb shark", "1.2 m [4'], possibly  larger shark",
#        "Two 2.1 m [7'] sharks", '3.5 m [11\'6"] shark captured',
#        'Blue pointer', "4.9 m [16'] shark",
#        "3.7 m to 4.6 m [12' to 15'] shark", 'Blacktail reef shark',
#        "2.4 m  [8'] shark", "2.7 m [9']  shark",
#        "3 m to 4.3 m [10' to 14'] shark", "5.5' shark", '20 kg shark',
#        "1.8 to 2.1 m [6' to 7'] shark",
#        "Bitten by several 1.8 m [6'] sharks",
#        "Said to involve 2 sharks: 5.2 m & 6 m [17' & 20'] ",
#        "1.4 m [4.5'] shark", "1.5 m to 1.8 m [5' to 6'] sharks",
#        '200-lb shark', "Sharks averaged 1.8 m [6'] in length",
#        '<1 m shark', 'Several sharks involved', ">3 m [10'] shark",
#        'Shark seen feeding on turtle scraps thrown overboard prior to incident.',
#        "3.7 m [12'] shark ", "2.3 m [7'] shark", '8-lb shark',
#        'Tooth fragments recovered from hull', "2.4 m [8']  shark",
#        "4 m [13'] shark x 6", "20' shark",
#        "Said to involve a >4 m [13'] shark", "3.7 [12'] shark",
#        "3 m [10'] shark seen in vicinity", '2 m [6\'9"] shark ',
#        ">6.7 m [22']  shark", '"Attacked by a number of sharks"',
#        '136-kg [300-lb] shark', '1,100-lb shark', "0.7 m [2.5'] shark",
#        '2.13 m shark',
#        "1.5 m to 1.8 m [5' to 6'] \x93spear-eye\x94 shark ",
#        "2.7 m [9'] shark with black-tipped pectoral fins",
#        '3.3 m [10\'9"] shark', "Said to be 6.4 m [21'] shark",
#        'Possibly C. leucas', '1.5 m, 45-kg shark',
#        '4.5  m [14\'9"] shark', '>1.6 m shark', "6 m [20']  shark",
#        "Said to involve a 6.5 m [21.5'] shark", '100-lb shark',
#        "2.6 m [8.5'] shark landed 2 hours later", "Blue pointer, 16'",
#        "18' shark", "2.6 m [8.5'] shark",
#        '2 days later a 600-lb shark was caught 100 yards from the site',
#        '3\' "blue nosed" shark', "0.9 m [3']  shark", '650-lb shark',
#        '2 sharks', "Blue pointer, 11' ",
#        "4.3 m [14'] shark seen in vicinity",
#        "4 m [13'] shark seen in vicinity",
#        "4.3 m [14'] shark seen in area previous week", "7' to 8' shark",
#        "4.4 m [14'] shark", "16' 800-lb shark", '"a school of sharks"',
#        "7 shark's teeth found embedded in the woodwork of the boat",
#        "Blue pointer, 12'",
#        "According to Carlsmith, the shark's mouth was 3' wide",
#        '"a very large shark"', '2.7 m [9\'] "blue" shark',
#        '"A pack of 6 sharks"',
#        "2.7 m [9'] shark later captured by Mitchell-Hedges",
#        "Comrades saw shark's tail appear about 5' away", "15'",
#        "3.7 m [12'], 1200-lb shark. Shark caught & its jaw exhibited at the Carnegie Museum",
#        'Shark involvement prior to death unconfirmed',
#        "3.7 m to 4.3 m [12' to 14']  shark",
#        "Said to involve a 2.7 m [9'] shark",
#        'A 20\' shark known as "Old Tom"', "13' shark",
#        'C. macrurus captured 48 hours after attack with tissue removed from man in its gut; species identified by G.P. Whitley,  reported as C. obscurus by  R. Steel',
#        "5.5' to 6' shark", 'Remains recovered from 3 sharks',
#        'Shark involvement probable', 'Remains recovered 5 days later',
#        'Fishermen recovered partial remains from shark a week later',
#        "1.8 m to 2.7 m [6' to 9'] shark", '70 kg shark', '3 sharks',
#        '13\'10" shark', "16' shark", '5\'7" shark',
#        'Unknown, but the shark was caught and put on exhibition',
#        "4.7 m [15.5'] shark",
#        'Shark was said to \x93have a very rough ½\x94-thick skin\x94',
#        "3 m [10'] sharks", 'Said to involve 2 sharks', '68" shark',
#        'Wobbegongs', 'Identified as C. gangeticus by Dr. J. Fayrer',
#        '"Shark caught later"', '4\' "ground shark"',
#        'Remains recovered from shark caught days later', '234-lb shark',
#        "Said to involve a 6 m to 7.3 m [20' to 24'] shark",
#        "Said to be a 7.6 m [25'] shark",
#        'Shovelnose guitarfish, adult male ', '"A pack of sharks"',
#        '"a black-tipped shark"'], dtype=object)

# %%
[i.replace(' shark', '') for i in program['Species_2'].unique() if isinstance(i,str)]
# Out:
# ['white',
#  '',
#  'tiger',
#  'lemon',
#  'bull',
#  'grey reef',
#  'tawny nurse',
#  'wobbegong',
#  'blacktip',
#  'galapagos',
#  'shark',
#  'nurse',
#  'cookiecutter',
#  'spinner',
#  'oceanic whitetip',
#  'sandtiger',
#  'blue',
#  'gill',
#  'caribbean reef',
#  'broadnose sevengill',
#  'reef',
#  'angel',
#  'dogfish',
#  'mako',
#  'silky',
#  'bronze whaler',
#  'hammerhead',
#  'foot',
#  'blacktip reef',
#  'raggedtooth',
#  'sandbar',
#  'tawney nurse',
#  'cow',
#  'whitetip reef',
#  'salmon',
#  'grey nurse',
#  'porbeagle',
#  'port jackson',
#  'sevengill',
#  'zambesi',
#  'thresher',
#  'bronze whale',
#  'cookie cutter',
#  'blackshark',
#  'white gill',
#  'starry smoothhound',
#  'basking',
#  'gray reef',
#  'sand',
#  'spotted catshark',
#  'catshark',
#  'black',
#  'copper',
#  'longfin mako',
#  'sevengill ',
#  'brown',
#  'shortfin mako',
#  'colored',
#  'reef colored',
#  'grey colored',
#  'bull tiger',
#  'bonnethed',
#  'whaler',
#  'black finned',
#  'blackshark blackfin',
#  'soupfin',
#  'leopard',
#  'black reef',
#  'grey',
#  'gaffed',
#  'zambezi',
#  'white',
#  'tipped reef',
#  'shot white',
#  'sandshark',
#  'gray',
#  'lemon bull',
#  'whale',
#  'carpet',
#  'dog',
#  'scalloped hammerhead',
#  'white thresher',
#  'red',
#  'banjo',
#  'hooked',
#  'blackshark blackshark',
#  'shark mako',
#  'been another',
#  'blue ',
#  'bull ',
#  'white reef',
#  'makoshark',
#  'mako aka makoshark',
#  'shovelnose',
#  'blue nose',
#  'nosed',
#  'cocktail',
#  'carcharhinid',
#  'whiptail',
#  'broadnose']

# %%
program = program.drop(['Species'], axis=1)

# %%
program['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'COSTA RICA',
#        'MALDIVES', 'SOUTH AFRICA', 'THAILAND', 'BAHAMAS', 'ECUADOR',
#        'MALAYSIA', 'CUBA', 'NEW ZEALAND', 'SPAIN', 'EGYPT',
#        'UNITED KINGDOM', 'PHILIPPINES', 'INDONESIA', 'COLUMBIA',
#        'FRENCH POLYNESIA', 'NEW CALEDONIA', 'UNITED ARAB EMIRATES',
#        'REUNION', 'FRANCE', 'JAMAICA', 'TONGA', 'SCOTLAND', 'ITALY',
#        'TAIWAN', 'PAPUA NEW GUINEA', 'RUSSIA', 'SEYCHELLES',
#        'TURKS & CAICOS', 'VIETNAM', 'MOZAMBIQUE', 'GUAM', 'CROATIA',
#        'PANAMA', 'SOLOMON ISLANDS', 'NORWAY', 'Sierra Leone', 'FIJI',
#        'ATLANTIC OCEAN', 'ST. MAARTIN', 'GRAND CAYMAN', 'CHINA',
#        'VANUATU', 'SOUTH KOREA', 'JAPAN', ' TONGA', 'URUGUAY',
#        'VENEZUELA', 'INDIA', 'MICRONESIA', 'CANADA', 'OKINAWA',
#        'MARSHALL ISLANDS', 'MAURITIUS', 'SENEGAL', 'EGYPT / ISRAEL',
#        'HONG KONG', 'EL SALVADOR', 'ANGOLA', 'CHILE', 'Fiji',
#        'DOMINICAN REPUBLIC', 'KENYA', 'PORTUGAL', 'ISRAEL', 'PALAU',
#        'WESTERN SAMOA', 'BRITISH ISLES', 'NEW BRITAIN', 'NEW GUINEA',
#        'RED SEA', 'FEDERATED STATES OF MICRONESIA', 'GREECE',
#        'BRITISH WEST INDIES', 'MID ATLANTIC OCEAN', 'PERSIAN GULF',
#        'NORTH PACIFIC OCEAN', 'NORTH SEA', 'BERMUDA', 'NICARAGUA ',
#        'SRI LANKA', 'NORTH ATLANTIC OCEAN', 'AMERICAN SAMOA',
#        'PACIFIC OCEAN', 'IRAN', 'MAYOTTE', 'MALTA', 'MONTENEGRO', 'YEMEN',
#        'ARGENTINA', 'SUDAN', 'NETHERLANDS ANTILLES', 'IRAQ',
#        'SOUTH ATLANTIC OCEAN', 'SLOVENIA', 'CURACAO', 'NICARAGUA',
#        'TRINIDAD & TOBAGO', 'HAITI', 'SAN DOMINGO', 'CYPRUS',
#        'SAUDI ARABIA'], dtype=object)

# %%
deadliest = program['Species_2'] == 'white shark' 
deadliest
# Out:
# 0        True
# 3       False
# 4       False
# 6       False
# 7       False
#         ...
# 6265    False
# 6266    False
# 6267    False
# 6274     True
# 6296    False
# Name: Species_2, Length: 2823, dtype: bool

# %%
program['Country'].value_counts().head()
# Out:
# USA             1136
# AUSTRALIA        680
# SOUTH AFRICA     354
# NEW ZEALAND       64
# BAHAMAS           54
# Name: Country, dtype: int64

# %%
white_shark = program[deadliest]
white_shark
# Out:
#            Country                   Area Fatal (Y/N)    Species_2
# 0              USA             California           N  white shark
# 22       AUSTRALIA      Western Australia           N  white shark
# 24    SOUTH AFRICA  Western Cape Province           N  white shark
# 34    SOUTH AFRICA  Eastern Cape Province           N  white shark
# 40       AUSTRALIA        New South Wales           N  white shark
# ...            ...                    ...         ...          ...
# 6021  SOUTH AFRICA  Western Cape Province           Y  white shark
# 6159         ITALY               Sardinia           Y  white shark
# 6162        FRANCE           Côte d'Azur            N  white shark
# 6245           USA             California           N  white shark
# 6274         ITALY           Adriatic Sea           N  white shark
#
# [610 rows x 4 columns]

# %%
white_shark.groupby('Country', sort=False).count().head(3)
# Out:
#               Area  Fatal (Y/N)  Species_2
# Country
# USA            199          199        199
# AUSTRALIA      148          148        148
# SOUTH AFRICA   161          161        161

# %%
program['Area'].unique()
# Out:
# array(['California', 'New South Wales', 'Colima', 'Pernambuco', 'Florida',
#        'Queensland', 'Cornwall', 'Westerm Australia', 'Cocos Island',
#        'Western Australia', 'Alifu Alifu Atoll', 'Western Cape Province',
#        'Hawaii', 'Hua Hin', 'New Providence', 'Alagoas',
#        'Eastern Cape Province', 'Victoria', 'KwaZulu-Natal',
#        'Boi Island, Victoria', 'Galapagos Islands', 'Fernando de Noronha',
#        'Sepang', 'Holquin Province', 'South Australia', 'North Island',
#        'Canary Islands', 'Massachusetts', 'South Carolina',
#        'Red Sea Protectorate', 'New Jersey', 'Majorca', 'Washington',
#        'Tabasco', 'South Devon', 'New Providence ', 'Luzon Island',
#        'Great Exuma', 'Bimini', 'Bali', 'Alicante Province',
#        'Abaco Islands', 'Alabama', 'Isla Provedencia', 'Texas',
#        'North Carolina', 'Suez', 'Tuamotos', 'Grand Terre',
#        'Santa Catarina State', 'Balneário Camboriú', 'Fujairah Emirate',
#        'Grand Canary Island', 'Phuket', 'Tasmania', 'Grand Bahama Island',
#        'Le Port', 'Rangiroa', 'Saint-Gilles-les-Bains', 'Bora Bora',
#        'Central Tuamotu', 'd\x92Étang-Salé', 'Moorea', 'Alicante',
#        'Louisiana', 'Saint-Leu', 'Delaware', 'Palmyra Atoll',
#        'Wallis and Futuna', 'Georgia', 'Society Islands', 'South Island',
#        'North Province', 'Oregon', 'Bay of Biscay', 'Exuma Islands',
#        'Santa Cruz Island', 'Saint-Gilles', 'Quintana Roo', 'Tuamotus',
#        'St. Catherine', 'Palawan', 'Mercury Islands', 'Sinaloa', "Vava'u",
#        'Inner Hebrides', 'Saint Leu', 'Sardinia', 'Guerrero', 'Taitung ',
#        'Moray', 'Central Province',
#        'Telyakovsky Bay, Khasan,  Primorsky Krai (Far East)', 'Praslin',
#        'Caicos Bank', 'Kedah', ' Loyalty Islands', 'West End',
#        'South Sinai Peninsula', 'Maine', 'New York', 'Binh Dinh Province',
#        'Sinai Peninsula', 'Saint-Benoit', 'Rio Grande Do Sul',
#        'Western Province', 'Torres Strait', 'Maputo Province',
#        'Inhambane Province', 'Fife', 'Devon', 'St. Johns Reef',
#        'Off Green Island', 'North Region', 'Strait of Malacca',
#        'Guantanamo Province', 'Red Sea', 'Northern Territory',
#        ' Split-Dalmatia Count,', 'North Devon', 'US Virgin Islands',
#        'San Carlos', 'Cabo San Lucas', 'Sussex', 'Easter Ross', 'Guerro',
#        'Northern Bahamas', 'Baja California', 'Loyalty Islands',
#        'Marovo Lagoon', 'Territory of Cocos (Keeling) Islands',
#        'Oslo Fjord', 'Virginia', 'Kent', 'Bird Island', 'Bimini Islands',
#        'South Province', 'Cook islans', 'Kentucky', 'Guam',
#        'Western Area', 'Vitu Levu', '300 miles from Antigua',
#        '600 nm west of the Canary Islands', 'Simpson Bay', 'East Wall',
#        'Shanghai', 'Malampa Province', "South Ch'ungch'ong Province",
#        'New Mexico', 'Santiago de Cuba Province', 'Camaguey Province',
#        'Conservatória District', 'South Carolina ',
#        'Kuril Islands in the Pacific', 'Wakayama Prefecture',
#        "Nuku'alofa", 'Saint-Benoît',
#        'South Island, near Karitane north of Dunedin', 'Rocha',
#        'Anzoategui', 'Tamil Nadu', 'Pearl Islands', 'Cook Islands',
#        'Johnston Atoll', 'Baatan', 'Nueva Esparta', 'Southland',
#        'North Pacific coast', 'Caroline Islands', 'Cheshire', 'Maryland',
#        'KwaZulu-Natal between Port Edward and Port St Johns',
#        'Guanacaste', 'Rayong Province', 'Taveuni', 'New Brunswick',
#        'Miyako Island', 'Saint-Pierre', 'Alaska', 'Minerva Reef',
#        'Worcestershire', 'Rio de Janeiro', 'Alinglaplap Atoll',
#        'Adriatic Sea', 'Ralik Chain', 'Grand Baie',
#        "L' Etang Salé-les-Bains", 'Southern Japan', 'Cap Vert Peninsula',
#        'Berry Islands', 'Transvaal', 'Gaza', 'Miyako', 'Chatham Islands ',
#        'South Sinai, Gulf of Aqaba', 'Missouri', 'Saint-Paul ',
#        'Chatham Islands, east of New  Zealand', 'Vava\x92u',
#        'Mississippi', 'Clearwater Bay', 'New Territories',
#        'Yasawa Islands', 'Aichi Prefecture', 'Saint-Denis',
#        'Saint-Joseph', 'La Libertad', 'Costa Blanca', 'Walkers Cay',
#        'Ehime Prefecture', 'Tongapatu Group', 'West Africa',
#        'Wakaya Island', 'Saint-Paul', 'Antarctic Ocean',
#        'La Saline-les-Bains', 'Ligurian Sea', "L'Etang-Salé",
#        'Port Shelter', 'Sainte-Marie', 'Tuscany', 'Tyrrhenian Sea',
#        'New Ireland', 'Valpariso Province', 'Vanua Levu',
#        'Between DR and Puerto Rico', 'Catalonia', 'Cádiz', 'Sicily',
#        'Central Philippines', 'North & South Carolina', 'Andros Islands',
#        'Chungnam', 'Coquimbo', "Grand'Anse", 'Lamu Archipelago',
#        'Los Vilos', 'Madeira Islands', 'Reggio Calabria Province',
#        ' Split-Dalmatia County', 'Florida ', 'Aulong Island',
#        'Western Caroline Islands', 'Upolu Island', 'Antibes',
#        'Illeginni Atoll', 'Istria County', 'Coast Province',
#        'Namonuito Atoll', 'Eastern Caroline Islands',
#        'Western Caroline Islands (North Pacific Ocean)', 'Limpopo River',
#        'Zadar County', 'Eleuthera', 'Magdalena Department',
#        'New Ireland Province', 'Out Islands', 'New Britain',
#        'Duke of York Islands', 'Primorje-Gorski Kotar County ',
#        'Taranto province', 'New Providence Island', 'West coast',
#        'Madang Province', 'East Sepik', 'Veracruz',
#        'East of the Gulf of Aqaba', 'Bougainville (North Solomons)',
#        'Victoria ', 'Puerto Rico', 'Northern Taiwan', 'San Blas',
#        'Caribbean Coast', 'Vita Levu', 'San Blas Islands',
#        'South Coast, East New Britain', 'Gulf Province', ' Lau Province',
#        'Ysabel Island', 'Santo Domingo', 'Thessaly',
#        'Lomaiviti  Island Group', 'Grand Turk Island', 'Sharon',
#        'Northern District', 'Off the Coromandel Peninsula, North Island',
#        'Madang', '10ºS, 142ºE', 'Kwajalein Atoll', 'Shefa Province',
#        '165  miles from Bermuda',
#        '25 km off the coast of Iran & 483km from mouth of Persian Gulf',
#        'Venice Province', 'Admiralty Islands, Manus Province',
#        'Wake Island (EnenKio)', 'Roncador Bank', 'Western District',
#        'In the English Channel ', 'Cook Strait',
#        'Unknown, treated at Wick, SCOTLAND', 'Paget', 'Madang (WO)',
#        'Pacific coast', 'Eastern  Province', 'Lomaiviti Province',
#        'Kadavu', 'Orissa', 'Istria', 'Okayama Prefecture',
#        'In the Gulf Stream ', ' Kikori River mouth', 'Milne Bay Province',
#        'South Chungcheong Province', 'Tutuila Island', 'Cat Cay',
#        'Primorje-Gorski Kotar County', 'Between Hawaii & Wake Island',
#        'Taipei Hsien', 'Canal Zone', 'West New Britain Province',
#        'Eniwetok Atoll', 'Havana Province', 'Karun River',
#        'Near Dakar, Cap Vert Peninsula', 'Mozambique Channel',
#        'Tyrrenian Sea', 'Congreve Channel', 'St. Thomas Bay',
#        'Corfu Island', '1000 miles west of Hawaii',
#        ' Primorje-Gorski Kotar County', 'Rhode Island', 'Aden',
#        'New Ireland, Bismarck Archipelago', 'Isles del Rosario',
#        'Wake Island', 'Isle of Man', 'South shore ',
#        'Buenos Aires Province', 'Nova Scotia', 'Genoa  Province',
#        'Teramo', 'Red Sea State', 'Curacao', ' La Libertad',
#        'Eastern Province', 'Southern Province', 'Jakarta Harbour',
#        'Attica', 'New Ireland Province, Bismarck Archipelago',
#        'Khuzestan Province', 'Basrah', '300 miles east of Luzon',
#        'Caribbean Sea', 'Gulf of Panama', 'Liguria', 'Cay Sal Bank',
#        'Off Libya', 'Panama Bay (Pacific Ocean)', 'Torres Strait ',
#        'Ascension Bay', 'Lower San Juan River', 'Basrah City', 'Trinidad',
#        'Queensland ', 'Argyllshire', 'Arran', 'Argyll', 'Newfoundland',
#        'Hamilton', 'Bay of Fundy', 'Viti Levu Island',
#        'Golfo di Genova in the Ligurian Sea', 'Vancouver', 'Tamaulipas',
#        'Dorset', 'Galica', 'Westmoreland Parish', 'Kingston Parish',
#        'Cape Haitien', 'Halifax',
#        '60 miles north of San Domingo in the West Indies', 'Balearics',
#        'Georges Bank', 'Hong Kong', 'Harare Province', 'Southern Cyprus',
#        'Calabria', 'Ratak ', 'Provence', 'Bay of Campeche', ' New Jersey',
#        "Côte d'Azur  ", 'Andaman Islands', 'Valencia', 'East Java',
#        'Hoogly River', 'Alpes Maritime', 'Edinburgh', 'Corfu ',
#        'Matanzas Province (north coast)', "Côte d'Azur ",
#        'Los Roques  Islands', 'Milne Bay  Province', 'Amirante Islands',
#        'Lake Nicaragua (fresh water)'], dtype=object)

# %%
white_shark.groupby('Area', sort=False).count().head(3)
# Out:
#                        Country  Fatal (Y/N)  Species_2
# Area
# California                 155          155        155
# Western Australia           40           40         40
# Western Cape Province      101          101        101

# %%
program_result = pd.DataFrame({'Fatal (Y/N)':['Y','',''],'Specie':['white shark','',''],'Occurrences Specie':['610','',''],'Country':['USA','AUSTRALIA','SOUTH AFRICA'],'Occurrences Country':['199','148','161'],
                               'Area':['California','Western Australia','Western Cape Province'],
                           'Occurrences Area':['155','40','101']})
program_result
# Out:
#   Fatal (Y/N)       Specie Occurrences Specie       Country  \
# 0           Y  white shark                610           USA
# 1                                                 AUSTRALIA
# 2                                              SOUTH AFRICA
#
#   Occurrences Country                   Area Occurrences Area
# 0                 199             California              155
# 1                 148      Western Australia               40
# 2                 161  Western Cape Province              101
