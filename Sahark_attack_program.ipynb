# %%
import pandas as pd
import numpy as pn

# %%
data = pd.read_csv('C:/Users/Maura Santos/Desktop/DA_FT_OUT/Modulo_1/archive(2)/attacks.csv', encoding='latin1', sep=',')
data
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(data.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
print(data.columns.tolist())
# Out:
# ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23']

# %%
shipwreck = data[['Case Number','Year','Country','Area','Fatal (Y/N)','Species ' ,'Location','Activity']]
shipwreck
# Out:
#       Case Number    Year    Country             Area Fatal (Y/N)  \
# 0      2018.06.25  2018.0        USA       California           N
# 1      2018.06.18  2018.0        USA          Georgia           N
# 2      2018.06.09  2018.0        USA           Hawaii           N
# 3      2018.06.08  2018.0  AUSTRALIA  New South Wales           N
# 4      2018.06.04  2018.0     MEXICO           Colima           N
# ...           ...     ...        ...              ...         ...
# 25718         NaN     NaN        NaN              NaN         NaN
# 25719         NaN     NaN        NaN              NaN         NaN
# 25720         NaN     NaN        NaN              NaN         NaN
# 25721         NaN     NaN        NaN              NaN         NaN
# 25722          xx     NaN        NaN              NaN         NaN
#
#               Species                         Location     Activity
# 0          White shark     Oceanside, San Diego County     Paddling
# ...

# %%
import seaborn as sns

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(shipwreck.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
shipwreck.iloc[16491]
# Out:
# Case Number    NaN
# Year           NaN
# Country        NaN
# Area           NaN
# Fatal (Y/N)    NaN
# Species        NaN
# Location       NaN
# Activity       NaN
# Name: 16491, dtype: object

# %%
shipwreck = shipwreck.drop(shipwreck.index[6453:])

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(shipwreck.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
shipwreck.dropna(axis=0,how='any',inplace=False)
# Out:
#        Case Number    Year       Country                          Area  \
# 0       2018.06.25  2018.0           USA                    California
# 3       2018.06.08  2018.0     AUSTRALIA               New South Wales
# 4       2018.06.04  2018.0        MEXICO                        Colima
# 6     2018.06.03.a  2018.0        BRAZIL                    Pernambuco
# 7       2018.05.27  2018.0           USA                       Florida
# ...            ...     ...           ...                           ...
# 6253       ND.0052     0.0     NICARAGUA  Lake Nicaragua (fresh water)
# 6265       ND.0038     0.0          IRAQ                        Basrah
# 6266       ND.0037     0.0  SAUDI ARABIA              Eastern Province
# 6267       ND.0036     0.0  SAUDI ARABIA              Eastern Province
# 6296       ND.0006     0.0     AUSTRALIA               New South Wales
#
#      Fatal (Y/N)                                           Species   \
# ...

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(shipwreck.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
shipwreck.dropna(thresh=5)
# Out:
#      Case Number    Year             Country               Area Fatal (Y/N)  \
# 0     2018.06.25  2018.0                 USA         California           N
# 1     2018.06.18  2018.0                 USA            Georgia           N
# 2     2018.06.09  2018.0                 USA             Hawaii           N
# 3     2018.06.08  2018.0           AUSTRALIA    New South Wales           N
# 4     2018.06.04  2018.0              MEXICO             Colima           N
# ...          ...     ...                 ...                ...         ...
# 6297     ND.0005     0.0           AUSTRALIA  Western Australia           Y
# 6298     ND.0004     0.0           AUSTRALIA  Western Australia           Y
# 6299     ND.0003     0.0                 USA     North Carolina           Y
# 6300     ND.0002     0.0              PANAMA                NaN           Y
# 6301     ND.0001     0.0  CEYLON (SRI LANKA)   Eastern Province           Y
#
# ...

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(shipwreck.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
shipwreck.dropna(subset=['Year','Country','Area','Fatal (Y/N)','Species ' ,'Location','Activity'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d184cba8f009> in <module>
# ----> 1 shipwreck.dropna(subset=['Case Number','Year','Country','Area','Fatal (Y/N)','Species ' ,'Location','Activity'])
#
# NameError: name 'shipwreck' is not defined

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(shipwreck.isnull(),cbar=False)
# Out:
# <AxesSubplot:>
